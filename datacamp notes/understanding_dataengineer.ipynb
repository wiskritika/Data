# %% [markdown]
# # Data structure

# %% [markdown]
# #### Structure Data
#
# - Easy to use
# - consistent model , rows and columns
# - defined types
# - can be grouped to form relation
# - stored in relational database
# - about 20% of the data is structured
# - created and queries using sql
#
# #### Semi-structure Data
#
# - Easy to search and organize
# - consistent model, less rigid implementation : different observations have different sizes
# - different types
# - can be grouped, but needs more work
# - NoSQL databases: json,xml,yaml

# %% [markdown]
# #### Unstructured Data
#
# - Does not follow a model , can't be contained in rows and column
# - difficult to search and organize
# - usually text, sound, pictures and videos
# - usually stored in data lakes, appears in data warehouses or databases
# - most of the data is unstructured
# - can be extremely valuable
#
# #### Adding some structure
#
# - Use AI to search and organize unstructured data
# - Add information to make it semi-structured

# %% [markdown]
# # SQL DATABASES

# %% [markdown]
# #### SQL
#
# - Structured query language
# - Industry standard for Realtional Database management system (RDBMS)
# - Allows you to access many records at once, and group, filter or aggregate them.
# - close to written english, easy to write and understand
# - data engineer use SQL to create and maintain databases.
# - data scientist use SQL to query (request information from) database
#
# #### Database schema
#
# - Databases are made of tables
# - the database schema governs how tables are realted
#
# #### Data lakes
#
# - It stores all raw data
# - Can be petabytes (1 million GBs)
# - store all data structure
# - cost effective
# - difficult to analyze
# - requires up to date data catalog
# - used by data scientists
# - big data, real time analytics
#
#
# #### Data warehouse
#
# - specific data for specific use
# - realtively small
# - stores mainly structured data
# - more costly to update
# - optimized for data analysis
# - also used by data analyst and business analyst
# - ad-hoc, read-only queries
#
#
# #### Data catalog for data lakes
#
# - what is the source of this data ?
# - where is the data used ?
# - who is the owner of the data ?
# - how often is this data updated ?
# - good practice in terms of data governance ?
# - ensure reproducibility
# - no catalog --> data swamp
# - good practice for any data storage solution (Reliabilty, Autonomy, Scability, speed)
#
#
# #### Database
#
# - general term
# - loosely defined as organized data stored and accessed on a computer
#
# #### Data warehouse
#
# - It is type of database

# %% [markdown]
# # Processing data

# %% [markdown]
# Data Processing : converting data into meaningful information
#
# ### Data processing value
#
# ##### conceptually
#
# - remove unwanted data
# - optimize memory, process and network cost
# - covert data from one type to another
# - organize data
# - to fit into schema/structure
# - increase productivity
#
# #### At Spotflix
#
# - No long term need for testing feature data
# - can't afford to store and stream files this big
# - covert songs from .flac to .ogg
# - recognize data from the data lake to data warehouse
# - employee table example
# - enable data scientist
#
# #### How data engineer process data ?
#
# - data manipulation, cleaning, and tidying task
# (that can be automated, that will always need to be done)
# - store data in a sanely structured database
# - rejecting corrupt song files
# - deciding what happens with mising metadata
# - separate artists and albumbs tables
# - but provide view combining them
# - indexing
#
# #### scheduling data
#
# - can apply to any task listed in data processing
# - scheduling is the glue of your system
# - holds each piece and organize how they work together
# - runs task in a specific order and resolves all dependencies
#
# #### Manually, time and sensor scheduling
#
# - manually
# - manually update the employee table
# - automatically run at specific time
# - update the employee table at 6AM
# - automatically run if specific condition met (sensor scheduling)
# - update the department tables if a new employee was added
#
# #### batches
#
# - group records at intervals
# - often cheaper
# - songs uploaded by artist
# - employee table
# - revenue table
#
# #### streams
#
# - send indiviuals records right away
# - new user signing in
# - another eg online vs offline listening
#
# #### scheduling tools
#
# - APACHE AIRFLOW
# - LUIGI

# %% [markdown]
# #### parallel computing
#
# - basic of modern data processing tools
# - neccessary (mainly because of memory, also for processing power)
# - how it works ?
# - split task up into several smaller subtask
# - distribute these subtasks over several computers
#
# #### Benifits and risk of parallel computing
#
# - employees = processing units
#
# Advantages
#
# - extra processing power
# - reduced memory footprint
#
# Disadvantages
#  - moving data incurs a cost
#  - communication time

# %% [markdown]
# ### Cloud Computing

# %% [markdown]
# #### servers on premises
#
# - Bought
# - Need space
# - electrical and maintenance cost
# - enough power for peak moment
# - processing power unused at quiter times
#
# #### serves on cloud
#
# - rented
# - don't need space
# - use just the resource we need
# - when we need them
# - the closer to the user the better
#
# #### cloud computing for data storage
#
# - data realibilty : data replication
# - risk with sensitive data
#
# #### Multicloud
#
# ###### pros
#
# - reducing reliance on a single vendor
# - cost-efficiences
# - local laws requiring certain data to be physcially present within the country
# - mitigating against disaster
#
# ###### cons
#
# - cloud provider try to lock in consumers
# - incompatibiltity
# - security and governance
