# %% [markdown]
# git = version control system is a tool that helps to track changes in code
#
# - it is popular
# - free and open source
# -fast and scalable

# %% [markdown]
# Github = website that allows developer to store and manage their code using git
#
# - configuring git
#
# git config --global user.name "Myname"
# git config --global user.name "someone@gmail.com"
# git config --list
#
# clone = cloning and repository on our local machine
#
# git clone <-some link->
#
# status = display the state of teh code (git status)
#
# Untracked  = new file that doesn't yet track
# modified = unchanged

# %% [markdown]
# add and commit
#
# Add = adds new or changes files in your working directory to the git staging area
#
# git add <--file name-->
#
# Commit = It is the record of change
#
# git commit -m "some message"

# %% [markdown]
# Push command
#
# push = upload local repo content to remote repo
#
# git push origin main
# git push -u origin main (get upstream)
#
# init command
#
# init = used  to create a new git repo
# git init
# git remote add origin <-link->
# git remote -v (to verify remote)
# git remote -M main(to remove branch)
# git push origin main

# %% [markdown]
# connect your local repo to github
#
# git init
# git add .
# git commit -m "Initial commit"
# git remote add origin <github-repo-url>
# git push origin main
#
# work flow
#
# github repo
# clone
# changes
# add .
# commit
# push

# %% [markdown]
# Branch command
#
# git branch (to check the branch),
#
# git branch -M main (rename branch),
#
# git checkout <-branch name->,
#
# git checkout -b <-new branch name-> (to create new branch),
#
# git branch -d <-branch name> (delete branch )

# %% [markdown]
# Merging command
#
# way 1
#
# git diff <--branch name--> (to compare commits, branches, files and more)
#
# git merge <--branch name-->
# (to merge 2 branch)
#
# way 2
#
# Create a pull request (PR)
#
# Pull request = it lets you tell others about changes you have pushed to a branch in a repository on github
#
# Pull command = git pull origin main
#
# It is used to fetch and download content from a remote repo and immediately updates the local repo to match the content.

# %% [markdown]
# Resolving merge conflicts
#
# An event that takes place when git is unable to automatically resolve differences in code between two commits
#
# -Undoing changes
#
# case 1 :staged changes
#
# git reset <--file name-->
# git reset
#
# case 2 : committed changes(for one commit)
#
# git reset HEAD ~1
#
# case 3 : committed changes (for many commits)
#
# git reset <--commit hash-->
# git reset <--hard <---commit hash---> (change in vs code as well)

# %% [markdown]
# Fork
#
# - A fork is a new repository that shares code and visibility settings with the original "upstream" repository.
#
# - Fork is a rough copy
